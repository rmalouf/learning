# %% [markdown]
# Discriminative learning
# =======================

# %%
import pandas as pd
import matplotlib.pyplot as plt

import ndl

# %matplotlib inline

# %precision 3
pd.set_option('display.precision', 3)

# %%
data = pd.DataFrame()
data['Cues'] = [('A','X'),('B','X')]
data['Outcomes'] = ['yes', 'no']
data['Frequency'] = [1,1]
data
# Out:
#      Cues Outcomes  Frequency
# 0  (A, X)      yes          1
# 1  (B, X)       no          1

# %%
W = [w['yes'] for w in ndl.rw(data, M=500, trajectory=True)]
W = pd.DataFrame(W)

# %%
for c in W.columns:
    plt.plot(W[c], label=c)
plt.legend(loc='upper center', bbox_to_anchor=(0.2, 0.975), ncol=3, fontsize='small')
plt.xlabel('Trial')
plt.ylabel('Weight')
fig = plt.gcf()
fig.set_size_inches(5,3.3)
plt.savefig('discrim1.pdf')

# %%
plt.plot(W['A']+W['X'], label='AX')
plt.plot(W['B']+W['X'], label='BX')

plt.legend(loc='upper center', bbox_to_anchor=(0.2, 0.975), ncol=3, fontsize='small')
plt.xlabel('Trial')
plt.ylabel('Activation')
fig = plt.gcf()
fig.set_size_inches(5,3.3)
plt.savefig('discrim2.pdf')
